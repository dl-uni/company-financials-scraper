# %% [markdown]
# # Data Collection Notebook

# %% [markdown]
# ## Imports and Reading Raw ASX Data

# %%
import pandas as pd
import numpy as np
import yfinance as yf

asx = pd.read_csv("ASX_Listed_Companies_23-06-2021_10-32-50_AEST.csv").drop_duplicates(subset="Company name")
asx_200 = (asx.sort_values(by=["Market Cap"], ascending=False, na_position="last")).head(200)

# Initialise dict of yf.ticker objects for each company in the ASX (200)
asx_200_codelist = asx_200["ASX code"].tolist()
ticker_dict = dict()

for code in asx_200_codelist:
    request_code = code + ".AX"
    ticker = yf.Ticker(request_code)
    ticker_dict[code] = ticker

# %% [markdown]
# ## Retrieve Company Financials
#
# ### Took about 20 minutes last time to run (ASX200 Only)

# %%
for code in ticker_dict:
    print(code)
    ticker = ticker_dict[code]
    income_statement = ticker.financials
    balance_sheet = ticker.balance_sheet
    quarterly_bs = ticker.quarterly_balance_sheet
    cash_flow_statement = ticker.cashflow
    sustainability = ticker.sustainability
    major_holders = ticker.major_holders
    
    # get historical market data
    hist = ticker.history(period="5y")
    
    income_statement.to_csv(f"IncomeStatements/{code}_IS.csv")
    balance_sheet.to_csv(f"BalanceSheets/{code}_BS.csv")
    quarterly_bs.to_csv(f"QuarterlyBS/{code}_QBS.csv")
    cash_flow_statement.to_csv(f"CashFlowStatements/{code}_CFS.csv")
    try:
        sustainability.to_csv(f"Sustainability/{code}_Sust.csv")
    except:
        print(f"{code} had no sustainability report")
        
    try: 
        major_holders.to_csv(f"MajorHolders/{code}_Holders.csv")
    except:
        print(f"{code} had no major holders data")
        
    try:
        hist.to_csv(f"PriceData/{code}_5YrPriceData.csv")
    except:
        print(f"{code} had no price data")
# Out:
# CBA
# BHP
# CSL
# WBC
# NAB
# ANZ
# FMG
# WES
# MQG
# WOW
# RMD
# RMD had no sustainability report
# RIO
# TLS
# TCL
# GMG
# APT
# APT had no sustainability report
# ALL
# AMC
# AMC had no sustainability report
# WPL
# REA
# COL
# COL had no sustainability report
# NCM
# JHX
# XRO
# XRO had no sustainability report
# NWS
# NWS had no sustainability report
# SHL
# URW
# URW had no sustainability report
# FPH
# FPH had no sustainability report
# QBE
# BXB
# COH
# SYD
# STO
# REH
# REH had no sustainability report
# ASX
# SCG
# RHC
# SUN
# S32
# IAG
# MEZ
# MEZ had no sustainability report
# NST
# NST had no sustainability report
# MGR
# DXS
# TAH
# TAH had no sustainability report
# SEK
# SEK had no sustainability report
# SGP
# TPG
# TPG had no sustainability report
# APA
# KLA
# KLA had no sustainability report
# BSL
# DMP
# DMP had no sustainability report
# JHG
# JHG had no sustainability report
# WTC
# WTC had no sustainability report
# CPU
# AIA
# AGG
# AGG had no sustainability report
# MFG
# MFG had no sustainability report
# GPT
# AFI
# AFI had no sustainability report
# MIN
# MIN had no sustainability report
# QAN
# QAN had no sustainability report
# MPL
# TWE
# LLC
# ORG
# ORG had no sustainability report
# CWN
# SPK
# SPK had no sustainability report
# MCY
# MCY had no sustainability report
# OSH
# BLD
# EVN
# EVN had no sustainability report
# NIC had no sustainability report
# NSR
# NSR had no sustainability report
# LFG
# LFG had no sustainability report
# SKC
# SKC had no sustainability report
# CMW
# CMW had no sustainability report
# ZIM
# ZIM had no sustainability report
# DRR
# DRR had no sustainability report
# UWL
# UWL had no sustainability report
# LFS
# LFS had no sustainability report
# BIN
# BIN had no sustainability report
# CQR
# CQR had no sustainability report
# PPT
# PPT had no sustainability report
# WPR
# WPR had no sustainability report
# SLK
# SLK had no sustainability report
# ABC
# ABC had no sustainability report
# CIP
# CIP had no sustainability report
# CNI
# CNI had no sustainability report
# ORE
# ORE had no sustainability report
# INA
# INA had no sustainability report
# CCP
# CCP had no sustainability report
# EVT
# EVT had no sustainability report
# WHC
# WHC had no sustainability report
# PNI
# PNI had no sustainability report
# WEB
# WEB had no sustainability report
# WAM
# WAM had no sustainability report
# TYR
# TYR had no sustainability report
# HUB
# HUB had no sustainability report
# BGA
# BGA had no sustainability report
# RRL
# RRL had no sustainability report
# ELD
# ELD had no sustainability report
# PPH
# PPH had no sustainability report
# PNV
# PNV had no sustainability report
# OGC
# OGC had no sustainability report
# AVN
# AVN had no sustainability report
# DDR
# DDR had no sustainability report
# NAN
# NAN had no sustainability report

# %%
ticker_dict["ABP"].balance_sheet.to_csv(f"BalanceSheets/ABP_BS.csv")

# %%
data = yf.download(
    tickers=request_string,
    period="1mo",
)
# Out:
# [*********************100%***********************]  200 of 200 completed

# %%
data
# Out:
#            Adj Close                                                       \
#               A2M.AX ABC.AX ABP.AX AFI.AX AGG.AX AGL.AX AIA.AX     ALD.AX
# Date
# 2021-05-24      5.42   3.36   2.97   7.48   6.68   8.26   6.77  29.020000
# 2021-05-25      5.33   3.40   3.00   7.47   6.53   8.18   6.81  28.969999
# 2021-05-26      5.31   3.34   2.98   7.51   6.68   8.24   6.68  29.090000
# 2021-05-27      5.33   3.31   2.95   7.51   6.45   8.19   6.70  29.350000
# 2021-05-28      5.54   3.33   3.01   7.50   6.18   8.27   6.82  29.170000
# 2021-05-31      5.52   3.32   3.01   6.03   6.28   8.12   6.85  28.549999
# 2021-06-01      5.66   3.23   3.01   7.56   6.50   8.03   6.91  28.760000
# 2021-06-02      5.72   3.36   3.04   7.55   6.27   8.35   7.09  28.559999
# 2021-06-03      5.70   3.24   3.06   7.53   6.15   8.66   7.12  29.150000
# 2021-06-04      5.70   3.20   3.05   7.65   6.10   8.82   7.14  29.629999
# 2021-06-07      5.82   3.14   3.09   7.59   6.00   9.08   7.13  29.809999
# 2021-06-08      5.70   3.17   3.12   7.63   6.00   9.15   7.11  29.750000
# 2021-06-09      5.70   3.20   3.12   7.68   5.74   9.16   7.20  29.719999
# 2021-06-10      5.51   3.21   3.20   7.78   5.75   9.30   7.15  29.650000
# 2021-06-11      5.72   3.26   3.17   7.79   5.77   9.32   6.98  29.340000
# 2021-06-15      6.03   3.26   3.17   7.65   5.56   9.36   6.98  28.969999
# 2021-06-16      5.92   3.30   3.20   7.62   5.44   9.41   7.01  29.320000
